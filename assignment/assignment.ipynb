# %% [markdown]
# ---
# # Assignment: Data Visualization using a Visualization Library
# ---
#
# #### In this assignment, you will conduct an exploratory data analysis with visualizations on an Olympic Athletes dataset.
#
# How to use this Notebook:
# -  Firstly, make sure you have completed [1. Setup](#1-setup).
# -  Secondly, complete [Task 1: Preprocessing](#task-1-preprocessing).
# -  Then, you can complete [Task 2: Summary Statistics](#task-2-summary-statistics) to [Task 6: Map Visualizations](#task-6-map-visualizations) in any order.
# -  Lastly, complete [Task 7: Submission](#task-7-submission).
#
# The various tasks contain Notebook cells with `TODO`s.
# - You need to complete all `TODO`s.
#
# Assignment files and folders.
# - The file `assignment.ipynb` is this Notebook.
# - The folder `data` contains:
#   - 4 `.csv` files with the data for this assignment.
#   - A `verify.pkl` file you can use to verify your solution in [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering).
# - The folder `figures` contains:
#   - 19 `.png` figures you can use to verify your solutions to the visualization tasks in [Task 3: Distribution Visualizations](#task-3-distribution-visualizations) to [Task 6: Map Visualizations](#task-6-map-visualizations).
#   - Your visualizations need to be similar, but not identical to, the sample visualizations.
#   - The sample visualizations are provided as an aid so that you know what to aim for.
#
# This Notebook contains:
#
# - [1. Setup](#1-setup)
#   - [Python Virtual Environment](#python-virtual-environment)
#   - [Python and Pip Version](#python-and-pip-version)
#   - [Python Packages](#python-packages)
#   - [Python Modules](#python-modules)
#   - [Pandas Configuration](#pandas-configuration)
#   - [Dataset](#dataset)
# - [Task 1: Preprocessing](#task-1-preprocessing)
#   - [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)
#   - [Task 1.2 Feature Measurement Scales](#task-12-feature-measurement-scales)
# - [Task 2: Summary Statistics](#task-2-summary-statistics)
#   - [Task 2.1 Missing Values](#task-21-missing-values)
#   - [Task 2.2 Unique Values](#task-22-unique-values)
#   - [Task 2.3 Value Counts](#task-23-value-counts)
#   - [Task 2.4 Central Tendency and Spread](#task-24-central-tendency-and-spread)
#   - [Task 2.5 Outliers](#task-25-outliers)
# - [Task 3: Distribution Visualizations](#task-3-distribution-visualizations)
#   - [Task 3.1 Visualize the Distribution of Male and Female Athletes](#task-31-visualize-the-distribution-of-male-and-female-athletes)
#   - [Task 3.2 Visualize the Distribution of Athletes' Age](#task-32-visualize-the-distribution-of-athletes-age)
#   - [Task 3.3 Visualize the Distribution of Athletes' Height](#task-33-visualize-the-distribution-of-athletes-height)
#   - [Task 3.4 Visualize the Distribution of Athletes' Weight](#task-34-visualize-the-distribution-of-athletes-weight)
#   - [Task 3.5 Visualize the Distribution in Height of Male and Female Athletes](#task-35-visualize-the-distribution-in-height-of-male-and-female-athletes)
#   - [Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes](#task-36-visualize-the-height-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes](#task-37-visualize-the-weight-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season](#task-38-visualize-height-per-type-of-medal-for-male-and-female-athletes-faceted-by-season)
#   - [Task 3.9 Visualize the Average Age per Sport](#task-39-visualize-the-average-age-per-sport)
#   - [Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals](#task-310-visualize-the-top-10-countries-regions-with-most-total-medals)
#   - [Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals](#task-311-visualize-the-top-10-atheletes-by-total-awarded-medals)
#   - [Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal](#task-312-visualize-the-age-height-and-weight-distribution-per-type-of-medal)
#   - [Task 3.13 Interpret a Box Plot's Visual Elements](#task-313-interpret-a-box-plots-visual-elements)
# - [Task 4: Trend Visualizations](#task-4-trend-visualizations)
#   - [Task 4.1 Visualize Body Mass Index (BMI) Over Time](#task-41-visualize-body-mass-index-bmi-over-time)
#   - [Task 4.2 Visualize Gender (Sex) Participation Over Time](#task-42-visualize-gender-sex-participation-over-time)
# - [Task 5: Correlation Visualizations](#task-5-correlation-visualizations)
#   - [Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`](#task-51-visualize-pairwise-correlations-of-athletes-age-height-and-weight-per-sex-with-a-pairplot)
#   - [Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`](#task-52-visualize-pairwise-correlations-of-the-numeric-features-with-a-heatmap)
#   - [Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`](#task-53-visualize-atheltes-weight-versus-height-per-sex-with-a-lineplot)
#   - [Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`](#task-54-visualize-atheltes-weight-versus-height-per-sex-with-a-scatterplot)
# - [Task 6: Map Visualizations](#task-6-map-visualizations)
#   - [Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries](#task-61-visualize-number-of-medals-on-a-map-for-the-nordic-countries)
# - [Task 7: Submission](#task-7-submission)
#   - [Task 7.1 Verify the Integrity of your Notebook](#task-71-verify-the-integrity-of-your-notebook)
#   - [Task 7.2 Submit the Assignment](#task-72-submit-the-assignment)

# %% [markdown]
# ---
# # Setup
# ---

# %% [markdown]
# ## Python Virtual Environment
#
# - Make sure you have downloaded the GitHub repository (which contains the assignment).
#   - **Alternative 1**: You can use the same `git clone` as in the workshops.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz
#     cd dataviz
#     ```
#
#   - **Alternative 2**: You can `git clone` the repository into another folder just for the assignment.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz_assignment
#     cd dataviz_assignment
#     ```
#
# - Make sure you have created a Python Virtual Environment as below.
#
#     ```bash
#     conda create -y -p ./.conda python=3.12
#     conda activate ./.conda
#     python -m pip install --upgrade pip
#     pip install ipykernel jupyter pylance numpy pandas matplotlib seaborn basemap pillow
#     # You can install more packages, but for this assignment you need (at least) the packages listed above
#     ```
#
# - Also make sure you have selected your Python Virtual Environment in your Notebook.
#   - In the top right of your Notebook, click `Select Kernel`.
#   - Choose your Python Virtual Environment.

# %% [markdown]
# ---
# ## Python and Pip Version
#
# Let's start by printing out the Python and Pip version you are using in your Python Virtual Environment.

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.14
# pip 25.2 from C:\Users\Husse\miniconda3\Lib\site-packages\pip (python 3.13)

# %% [markdown]
# ---
# ## Python Packages
#
# Let's also make sure the necessary Python packages are installed in our Python Virtual Environment.
# - I have included some default packages below (many of which might already be installed in your Python Virtual Environment).
# - If you use any other `pip` or `conda` packages, add them in the cell below.
#   - Use `%pip install <package>` for Pip packages.
#   - Use `%conda install <package>` for Conda packages.
#
#
# Note
# - When you install a `conda` package, you might have to restart your Jupyter Notebook kernel.
# - To restart your Jupyter Notebook kernel, click the `Restart` button at the top of the Notebook.

# %%
# %pip install ipykernel
# %pip install jupyter
# %pip install pylance
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install basemap
# %pip install pillow
# Out:
# Requirement already satisfied: ipykernel in c:\Users\Husse\dataviz\.conda\Lib\site-packages (7.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (9.17.1)
# Requirement already satisfied: jupyter-client>=8.9.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (8.10.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: packaging>=22 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (27.2.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (6.5.8)
# Requirement already satisfied: traitlets>=5.4.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel) (5.16.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.11.7)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.2)
# Requirement already satisfied: pure-eval in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyter in c:\Users\Husse\dataviz\.conda\Lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (7.6.2)
# Requirement already satisfied: jupyter-console in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipykernel in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (7.3.0)
# Requirement already satisfied: ipywidgets in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (8.1.9)
# Requirement already satisfied: jupyterlab in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter) (4.6.3)
# Requirement already satisfied: comm>=0.1.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (9.17.1)
# Requirement already satisfied: jupyter-client>=8.9.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (8.10.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (1.7.2)
# Requirement already satisfied: packaging>=22 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (27.2.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (6.5.8)
# Requirement already satisfied: traitlets>=5.4.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipykernel->jupyter) (5.16.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.11.7)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.2)
# Requirement already satisfied: pure-eval in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipywidgets->jupyter) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from ipywidgets->jupyter) (3.0.17)
# Requirement already satisfied: async-lru>=1.0.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-builder>=1.0.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (1.2.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (2.21.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: anyio in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.15.0)
# Requirement already satisfied: certifi in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (5.11.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.26.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0.5)
# Requirement already satisfied: send2trash>=1.8.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.9.2)
# Requirement already satisfied: babel>=2.10 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.22.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.1)
# Requirement already satisfied: pycparser in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.9.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2026.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylance in c:\Users\Husse\dataviz\.conda\Lib\site-packages (11.0.0)
# Requirement already satisfied: pyarrow>=14 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pylance) (25.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pylance) (2.3.5)
# Requirement already satisfied: lance-namespace<0.9,>=0.8.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pylance) (0.8.6)
# Requirement already satisfied: lance-namespace-urllib3-client==0.8.6 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from lance-namespace<0.9,>=0.8.5->pylance) (0.8.6)
# Requirement already satisfied: pydantic>=2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (2.13.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.7.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (4.16.0)
# Requirement already satisfied: urllib3<3.0.0,>=1.25.3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (2.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pydantic>=2->lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pydantic>=2->lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pydantic>=2->lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.8.2->lance-namespace-urllib3-client==0.8.6->lance-namespace<0.9,>=0.8.5->pylance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\Users\Husse\dataviz\.conda\Lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\Users\Husse\dataviz\.conda\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\Husse\dataviz\.conda\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.23 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\Users\Husse\dataviz\.conda\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: basemap in c:\Users\Husse\dataviz\.conda\Lib\site-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (2.3.5)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (3.10.9)
# Requirement already satisfied: pyproj<3.8,>=3.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.5.1)
# Requirement already satisfied: pillow>=8 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from pyproj<3.8,>=3.0->basemap) (2026.7.22)
# Requirement already satisfied: six>=1.5 in c:\Users\Husse\dataviz\.conda\Lib\site-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->basemap) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in c:\Users\Husse\dataviz\.conda\Lib\site-packages (12.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Python Modules
#
# Let's import the necessary Python modules from the installed Python packages.
# - Numpy and Pandas are used for data mangling.
# - Matplotlib and/or Seaborn are used for visualizations.
# - If you need more imports, add them in the cell below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ---
# ## Pandas Configuration
#
# Let's also configure Pandas to set the maximum number of rows and columns displayed from a `DataFrame` in a Jupyter Notebook cell.
# - Configuring the maximum number of rows.
#   - `pd.set_option('display.max_rows', None)` displays an unlimited number of rows (don't use this when working with large `DataFrame`s).
#   - `pd.set_option('display.max_rows', 25)` displays a maximum of `25` rows.
#   - `pd.reset_option('display.max_rows')` resets the number of rows to the default setting.
# - Configuring the maximum number of columns.
#   - `pd.set_option('display.max_columns', None)` displays an unlimited number of columns.
#   - `pd.set_option('display.max_columns', 25)` displays a maximum of `25` columns.
#   - `pd.reset_option('display.max_columns')` resets the number of columns to the default setting.

# %%
pd.reset_option('display.max_rows')        # show default number of rows
pd.set_option('display.max_columns', None) # show all columns

# %% [markdown]
# ---
# ## Dataset
#
# Let's load a pre-processed dataset containing information about Olymic athletes, events they competed in, etc., and inspect the features (columns).
# - `ID` is a unique identifier for an athlete.
# - `Name` is the athlete's name.
# - `Sex` is the athlete's sex, `M` for Male, or `F` for female.
# - `Age` is the athlete's age, for a specific `Year`.
# - `Height` is the athlete's height in centimeters (cm).
# - `Weight` is the athlete's weight in kilograms (kg).
# - `BMI` is the athlete's Body Mass Index, calculated as the weight (in kilograms) divided by the height (in meters): $BMI = \frac{Weight[kg]}{Height[m]^2}$
# - `Team` is the Olympic team the athlete is a member of.
# - `NOC` is the National Olympic Committee country code for the athlete.
# - `Region` is the region associated with the athlete's `NOC`.
# - `ISO3` is the ISO 3166-1 alpha-3 country code (a 3-letter code) for the athlete's country.
# - `Country` is the country name associated with the `ISO3` country code.
# - `Latitude` is the country's geographic latitude.
# - `Longitude` is the country's geographic longitude.
# - `Games` is the name of the Olymic games, e.g. `1992 Summer` for the 1992 summer games.
# - `Year` is the year of the Olymipc games.
# - `Season` is the season for the Olymipc games, i.e. `Summer` or `Winter`.
# - `City` is the city in which the Olymic games were held.
# - `Sport` is Olympic sport the athlete competed in.
# - `Event` is Olympic event the athlete competed in.
# - `Medal` is medal (Gold, Silver, Bronze) awarded to the athlete, if any.

# %%
df_verify = pd.read_pickle('data/verify.pkl')
print(f'Number of rows: {df_verify.shape[0]}')
print(f'Number of columns: {df_verify.shape[1]}')
df_verify.head() # head() displays the first 5 rows, head(10) displays the first 10 rows, etc.
# Out:
# Number of rows: 269731
# Number of columns: 21
#    ID                      Name Sex   Age  Height  Weight        BMI  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  24.691358
# 1   2                  A Lamusi   M  23.0   170.0    60.0  20.761246
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        NaN
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN        NaN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  23.959094
#
#              Team  NOC       Region ISO3      Country  Latitude  Longitude  \
# 0           China  CHN        China  CHN        China      35.0     105.00
# 1           China  CHN        China  CHN        China      35.0     105.00
# 2         Denmark  DEN      Denmark  DNK      Denmark      56.0      10.00
# 3  Denmark/Sweden  DEN      Denmark  DNK      Denmark      56.0      10.00
# 4     Netherlands  NED  Netherlands  NLD  Netherlands      52.5       5.75
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# Let's also print out the data types for the various features (columns).

# %%
df_verify.dtypes
# Out:
# ID             int64
# Name          object
# Sex           object
# Age          float64
# Height       float64
# Weight       float64
# BMI          float64
# Team          object
# NOC           object
# Region        object
# ISO3          object
# Country       object
# Latitude     float64
# Longitude    float64
# Games         object
# Year           int64
# Season        object
# City          object
# Sport         object
# Event         object
# Medal         object
# dtype: object

# %% [markdown]
# ---
# # Task 1: Preprocessing
# ---
#
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering
#
# Your first task is to load and preprocess the four `.csv` files in the `data` folder.
# - `athlete_events.csv` contains data about the athletes and events they competed in.
# - `geo.csv` contains ISO3 country codes with latitudes and longitides.
# - `noc_iso3.csv` contains mappings between NOC and ISO3 country codes.
# - `noc_regions.csv` contains NOC country codes with regions.
#
# When you are done, you should end up with **one** Pandas `DataFrame` (`df`) identical to the Pandas `DataFrame` (`df_verify`) above.
# - It should contain:
#   - The exact same column names (including large/small letters), in the same left-to-right order, and with the same data types.
#   - The same number of rows.
# - Once you have created your own DataFrame `df`, you can verify it by comparing it to the `df_verify` DataFrame (see cell below).
#
# Things to consider:
# - Remove all duplicates.
#   - This can be done using `df.drop_duplicates()` which considers complete rows with identical values as duplicates.
#   - Or, if you only want to consider a subset of the columns for each row as duplicates, you can use `df.drop_duplicates(subset='col')` where `col` is the column name.
#   - To print out the number of duplicates, you can use `df.duplicated().sum()`, or `df['col'].duplicated().sum()` for a specific column.
# - The `geo.csv` dataset contains unwanted characters in multiple columns, including columns with the wrong data types, and duplicate values in the `ISO3` column.
#   - When removing duplicates from this dataset, consider using `drop_duplicates(subset='ISO3')`.
# - When merging `DataFrames`, make sure you end up with the same number of rows as in the `athlete_events.csv` file (but with duplicates removed).
# - You will also have to compute the BMI column and add it to the `DataFrame` (see equation above).
# - Rename columns to match the column names in the `df_verify` DataFrame.
# - Reorder columns to match the column order in the `df_verify` DataFrame.

# %%
df_athletes = pd.read_csv('data/athlete_events.csv')
df_geo = pd.read_csv('data/geo.csv')
df_noc_iso3 = pd.read_csv('data/noc_iso3.csv')
df_noc_regions = pd.read_csv('data/noc_regions.csv')

df_athletes = df_athletes.drop_duplicates()
df_geo.columns = df_geo.columns.str.strip()
df_geo = df_geo.drop_duplicates(subset='Alpha-3 code')

merged = pd.merge(df_athletes, df_noc_iso3, on='NOC', how='left')
merged = pd.merge(merged, df_noc_regions[['NOC', 'region']], on='NOC', how='left')

df_geo['ISO3'] = df_geo['Alpha-3 code'].str.replace('"', '').str.strip()
geo_subset = df_geo[['ISO3', 'Country', 'Latitude (average)', 'Longitude (average)']].rename(
    columns={
        'Latitude (average)': 'Latitude',
        'Longitude (average)': 'Longitude'
    }
)

merged = pd.merge(merged, geo_subset, on='ISO3', how='left')

height_m = merged['Height'] / 100.0
merged['BMI'] = merged['Weight'] / (height_m ** 2)

merged.rename(columns={'region': 'Region'}, inplace=True)

df_verify = pd.read_pickle('data/verify.pkl')

df = merged[df_verify.columns].copy()

for col, dtype in df_verify.dtypes.items():
    if col in ['Latitude', 'Longitude']:
        df[col] = pd.to_numeric(df[col].astype(str).str.replace('"', ''), errors='coerce').astype(dtype)
    else:
        try:
            df[col] = df[col].astype(dtype)
        except Exception:
            pass

# %%
# Verify your 'df' DataFrame  is identical to the 'df_verify' DataFrame.
# The output from this cell should be 'True' if the two DataFrames are identical.
(df.dtypes == df_verify.dtypes).all() and df.shape == df_verify.shape and df.equals(df_verify)
# Out:
# True

# %% [markdown]
# ---
# ## Task 1.2 Feature Measurement Scales
#
# Characterize each feature (column) using [Stevens’ four levels of measurement](https://en.wikipedia.org/wiki/Level_of_measurement) below:
# - Nominal
# - Ordinal
# - Interval
# - Ratio

# %%
# TODO: Write your answer here.

# ------------------------------------------------------------------------------------------------------------------
# Feature   | Measurement Scale (mark 1 with an 'x') | Rationale 
# (Column)  | Nominal : Ordinal : Interval : Ratio   | (Why did you choose that measurement scale for that feature?)
# ------------------------------------------------------------------------------------------------------------------
# ID        |   x     :         :          :         | Unique identifier with no numerical meaning.
# Name      |   x     :         :          :         | Categorical text data with no order.
# Sex       |   x     :         :          :         | Categorical classes (M/F) with no ordering.
# Age       |         :         :          :   x     | Numerical value with a true absolute zero point.
# Height    |         :         :          :   x     | Continuous numerical scale with a true zero.
# Weight    |         :         :          :   x     | Continuous numerical scale with a true zero.
# BMI       |         :         :          :   x     | Continuous numerical scale with a true zero.
# Team      |   x     :         :          :         | Categorical team names with no order
# NOC       |   x     :         :          :         | Categorical country code with no order.
# Region    |   x     :         :          :         | Categorical region name with no order.
# ISO3      |   x     :         :          :         | Categorical country code with no order.
# Country   |   x     :         :          :         | Categorical country name with no order.
# Latitude  |         :         :     x    :         | Numerical scale with an arbitrary zero point (Equator).
# Longitude |         :         :     x    :         | Numerical scale with an arbitrary zero point (Prime Meridian).
# Games     |   x     :         :          :         | Categorical text combining year and season.
# Year      |         :         :     x    :         | Time scale with an arbitrary zero (calendar year).
# Season    |   x     :         :          :         | Categorical categories (Summer/Winter).
# City      |   x     :         :          :         | Categorical city name with no order.
# Sport     |   x     :         :          :         | Categorical sport name with no order.
# Event     |   x     :         :          :         | Categorical event name with no order.
# Medal     |         :    x    :          :         | Ordered categories (Gold > Silver > Bronze).

# %% [markdown]
# ---
# # Task 2: Summary Statistics
# ---

# %% [markdown]
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 2.1 Missing Values
#
# How many missing values are there per column?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > ID                0
# > Name              0
# > Sex               0
# > Age            9315
# > Height        58814
# > Weight        61527
# > BMI           62891
# > Team              0
# > NOC               0
# > Region          370
# > ISO3              0
# > Country          96
# > Latitude         96
# > Longitude        96
# > Games             0
# > Year              0
# > Season            0
# > City              0
# > Sport             0
# > Event             0
# > Medal        229959
# > ```
#
# </details>

# %%
# TODO: Write your code here to tablulate the number of missing values per column.

df.isna().sum()
# Out:
# ID                0
# Name              0
# Sex               0
# Age            9315
# Height        58814
# Weight        61527
# BMI           62891
# Team              0
# NOC               0
# Region          370
# ISO3              0
# Country          96
# Latitude         96
# Longitude        96
# Games             0
# Year              0
# Season            0
# City              0
# Sport             0
# Event             0
# Medal        229959
# dtype: int64

# %% [markdown]
# Given your result from above, would it be possible to impute (replace) the missing values for the affected features (columns)?
# - Don't drop any rows or columns with missing values, or impute (replace) any missing values.
# - You only have to answer the question stated above.

# %%
# TODO: Write your answer here.

# Yes, it is possible to impute numerical values (such as height and weight) using e.g. the mean or median. For columns like Medal, missing values can be interpreted as no medal being won, but this requires domain knowledge to be handled correctly.

# %% [markdown]
# ---
# ## Task 2.2 Unique Values
#
# How many unique values does the `Region` feature (column) contain?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 206
# > ```
#
# </details>

# %%
# TODO: Write your code here to print out the number of unique values in the `Region` feature (column).

df['Region'].nunique(dropna=False)
# Out:
# 206

# %% [markdown]
# ---
# ## Task 2.3 Value Counts
#
# How many instances of each value are there in the `Medal` feature (column)?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > Gold      13369
# > Bronze    13295
# > Silver    13108
# > ```
#
# </details>

# %%
# TODO: Write your code here to count the number of Gold, Silver, and Bronze medals.
# Out:
# Medal
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Task 2.4 Central Tendency and Spread
#
# How are the values in the numeric features (columns) distributed?
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# >                  ID             Age          Height          Weight             BMI        Latitude       Longitude            Year
# > count 269731.000000   260416.000000   210917.000000   208204.000000   206840.000000   269635.000000   269635.000000   269731.000000
# > mean   68264.949591       25.454776      175.338953       70.701778       22.784470       38.357629       14.336823     1978.623073
# > std    39026.253843        6.163869       10.518507       14.349027        2.912083       23.797926       64.719581       29.752055
# > min        1.000000       10.000000      127.000000       25.000000        8.360954      -41.000000     -176.200000     1896.000000
# > 25%    34655.500000       21.000000      168.000000       60.000000       20.957171       36.000000       -2.000000     1960.000000
# > 50%    68233.000000       24.000000      175.000000       70.000000       22.530864       46.000000       12.833300     1988.000000
# > 75%   102111.000000       28.000000      183.000000       79.000000       24.212293       52.500000       26.000000     2002.000000
# > max   135571.000000       97.000000      226.000000      214.000000       63.901580       65.000000      178.000000     2016.000000
# > ```
#
# </details>

# %%
# TODO: Write your code here shows the count, mean, std, min, max, 25th percentile, 50th percentile, and 75th percentile for the numeric columns.

# %% [markdown]
# ---
# ## Task 2.5 Outliers
#
# How many outliers are there in the `Age` feature (column)?
# - Numerous methods exist to detect [Outliers](https://en.wikipedia.org/wiki/Outlier) mathematically.
# - One such method uses the [1.5 x IQR Rule](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/identifying-outliers-iqr-rule), where **IQR** is the **Inter Quartile Range**.
#   - The first Quartile (`Q1`) is the same as the `25th Percentile`.
#   - The second Quartile (`Q2`) is the same as the `50th Percentile`.
#   - The third Quartile (`Q3`) is the same as the `75th Percentile`.
#   - The fourth Quartile (`Q4`) is the same as the `100th Percentile`.
#   - The Inter Quartile Range (`IQR`) is defined as: `IQR = Q3 - Q1`.
#   - The `1.5 x IQR Rule` states that:
#     - Any data point that lies below `Q1 - 1.5 * IQR` is considered an outlier.
#     - Any data point that lies above `Q3 + 1.5 * IQR` is considered an outlier.
#
# Pandas `Series` have a method `quantile()` to calculate Quantiles.
# - `Q1 = quantile(0.25)`
# - `Q3 = quantile(0.75)`
#
# Note on **Quantiles** vs **Quartiles** vs **Percentiles**
# - A **Quantile** is a general partition (subdivision) of values, e.g. a 0.05, 0.10, 0.25, or 0.76 fraction of the values.
# - A **Quartile** is also a type of **Quantile**, but **Quartiles** partition values into four disjoint subsets 1st, 2nd, 3rd and 4th quarter of the values.
# - A **Percentile** is also a type of **Quantile**, but **Percentiles** partition values between 0% to 100% of the values.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 9421
# > ```
#
# </details>

# %%
# TODO: Write your code here to calculate and print out the number of outliers in the `Age` feature (column).

# %% [markdown]
# ---
# # Task 3: Distribution Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 3.1 Visualize the Distribution of Male and Female Athletes
#
# Create a visualization showing the number of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_1.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of Male and Female athletes.

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Sex', hue='Sex', palette='Set2', legend=False)
plt.title('Number of Male and Female Athletes')
plt.show()
# Out:
# C:\Users\Husse\AppData\Local\Temp\ipykernel_9964\3619150984.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sex', palette='Set2')

# %% [markdown]
# ---
# ## Task 3.2 Visualize the Distribution of Athletes' Age
#
# Create a visualization showing the athlete Age distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_2.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Age.

# %% [markdown]
# ---
# ## Task 3.3 Visualize the Distribution of Athletes' Height
#
# Create a visualization showing the athlete Height distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_3.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Height.

# %% [markdown]
# ---
# ## Task 3.4 Visualize the Distribution of Athletes' Weight
#
# Create a visualization showing the athlete Weight distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_4.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Weight.

# %% [markdown]
# ---
# ## Task 3.5 Visualize the Distribution in Height of Male and Female Athletes
#
# Create a visualization showing the height distribution (counts, frequencies) of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_5.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution in height of Male and Female athletes.

# %% [markdown]
# ---
# ## Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_6.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete height per type of medal for Male and Female athletes.

# %% [markdown]
# ---
# ## Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete weight per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_7.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete weight per type of medal for Male and Female athletes.

# %% [markdown]
# ---
# ## Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes, faceted (grouped) by Season (Summer, Winter).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_8.png" width=1100></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the athelete height per type of medal for Male and Female athletes, grouped (faceted) by Season.

# %% [markdown]
# ---
# ## Task 3.9 Visualize the Average Age per Sport
#
# Create a visualization showing the average athelete Age per Sport (Curling, Triathlon, Handball, Tennis, Gymastics, Football, etc.).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_9.png" width=1500></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the average athelete Age per Sport.

# %% [markdown]
# ---
# ## Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals
#
# Create a visualization showing the number of total medals (gold, silver and bronze) awarded per country (region), for the top ten countries (regions) with most medals.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_10.png" width=1000></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the top 10 countries (regions) with most total medals.

# %% [markdown]
# ---
# ## Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals
#
# Create a visualization showing the top ten athletes by total number of awarded medals (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_11.png" width=1000></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the top 10 athletes per total awarded Medals.

# %% [markdown]
# ---
# ## Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal
#
# Create three `subplots`, side-by-side, for comparison purposes:
# 1. Create a visualization using a `boxplot` showing the Age distribution per medal type (gold, silver and bronze).
# 2. Create a visualization using a `boxplot` showing the Height distribution per medal type (gold, silver and bronze).
# 3. Create a visualization using a `boxplot` showing the Weight distribution per medal type (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_12.png" width=1500></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the Age, Height and Weight distribution per type of Medal.

# %% [markdown]
# ---
# ## Task 3.13 Interpret a Box Plot's Visual Elements
#
# A Box Plot (a.k.a. Box-and-Whiskers Plot) resembles a "Box" with "Whiskers" extending from the "Box" and usually some points below and above the "Whiskers".
#
# What information is shown in a  Box plot?
#
# - What does the "Box" represent?
# - What does the "line" inside the "Box" represent?
# - What does "Box's" lower "line" (bottom of the "Box") represent?
# - What does "Box's" upper "line" (top of the "Box") represent?
# - What does the lower "whisker" represent?
# - What does the upper "whisker" represent?
# - What do the data points below the lower "whisker" and above the upper "whisker" represent?

# %%
# TODO: Write your answer here.

# The "Box" represents ...
# The "line" inside the "Box" represents ...
# THe "Box's" lower "line" (bottom of the "Box") represents ...
# The "Box's" upper "line" (top of the "Box") represents ...
# The lower "whisker" represents ...
# The upper "whisker" represents ...
# The data points below the lower "whisker" and above the upper "whisker" represent ...

# %% [markdown]
# ---
# # Task 4: Trend Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 4.1 Visualize Body Mass Index (BMI) Over Time
#
# Create a visualization showing the Body Mass Index (BMI) over time (years) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_1.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize Body Mass Index (BMI) over time (years) per Sex (Male, Female).

# %% [markdown]
# ---
# ## Task 4.2 Visualize Gender (Sex) Participation Over Time
#
# Create a visualization showing the number of Male and Female athletes over time (years).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_2.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize gender participation over time.

# %% [markdown]
# ---
# # Task 5: Correlation Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`
#
# Create a `pairplot` showing the pariwise correlations of athlete Age, Height and Weight, color-coded by Sex (Male, Female).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of athlete Age, Height and Weight per Sex using a pair plot.

# %% [markdown]
# ---
# ## Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`
#
# Create a `heatmap` showing the pariwise correlations of the numeric features (columns).
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
# - Hint: a Pandas DataFrame has a `corr()` method.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_2.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of the numeric featues (columns) using a heat map.

# %% [markdown]
# ---
# ## Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `lineplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_3.png" width=1400></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a line plot.

# %% [markdown]
# ---
# ## Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `scatterplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_4.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a scatter plot.

# %% [markdown]
# ---
# # Task 6: Map Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries
#
# Create a visualization showing the number of Medals awarded for the nordic countries (Sweden, Norway, Denmark, Finland).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_6_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the number of Medals on a Map for the nordic countries.

# %% [markdown]
# ---
# # Task 7: Submission
# ---

# %% [markdown]
# ## Task 7.1 Verify the Integrity of your Notebook

# %% [markdown]
# The final task is to verify your Notebook before submitting it, and of course submitting it via Canvas.
#
# - Have you included any additional packages you might have used in your Notebook under [Python Packages](#python-packages)?
# - Have you imported any additional modules you might have used in your Notebook under [Python Modules](#python-modules)?
# - Is your Pandas DataFrame (`df`) identical to the DataFrame `df_verify` under [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)?
# - Have you completed all tasks (`TODOs`) in the Notebook?
# - Have you reflected over your visualizations (semiology, expressiveness, effectiveness, etc.)?
#
# When you are done:
# - Click the `Restart` button at the top of the Notebook to restart the Jupyter Notebook kernel.
# - Then click the `Run All` button at the top of the Notebook, to execute all Notebook cells.
#   - Check that all Notebook cells executed successfully with the desired results.

# %% [markdown]
# ---
# ## Task 7.2 Submit the Assignment

# %% [markdown]
# - Save you Notebook and submit it via [Canvas](https://hb.instructure.com/courses/11981/assignments/50258) before the deadline (only submit one `.ipynb` file).
